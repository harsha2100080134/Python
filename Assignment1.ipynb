# %%
import pandas as pd
df=pd.read_csv("modified_data.csv")
print(df)
# Out:
#             date       price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-05-02   313000.00       3.0       1.50         1340      7912
# 1     2014-05-02  2384000.00       5.0       2.50         3650      9050
# 2     2014-05-02   342000.00       3.0       2.00         1930     11947
# 3     2014-05-02   420000.00       3.0       2.25         2000      8030
# 4     2014-05-02   550000.00       4.0       2.50         1940     10500
# ...          ...         ...       ...        ...          ...       ...
# 4595  2014-07-09   308166.67       3.0       1.75         1510      6360
# 4596  2014-07-09   534333.33       3.0       2.50         1460      7573
# 4597  2014-07-09   416904.17       3.0       2.50         3010      7014
# 4598  2014-07-10   203400.00       4.0       2.00         2090      6630
# 4599  2014-07-10   220600.00       3.0       2.50         1490      8102
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df1 = df.groupby('price')['sqft_living'].max()
print(df1)
# Out:
# price
# 0.0            8020
# 7800.0          780
# 80000.0         430
# 83000.0         900
# 83300.0        1490
#               ...
# 4489000.0      6430
# 4668000.0      9640
# 7062500.0     10040
# 12899000.0     2190
# 26590000.0     1180
# Name: sqft_living, Length: 1741, dtype: int64

# %%
row = df.loc[df["price"].idxmax()]
print("floors:", row["floors"])
print("sqft_living:", row["sqft_living"])
# Out:
# floors: 1.0
# sqft_living: 1180

# %%
max_index = df["price"].idxmin()
print(max_index)
# Out:
# 4354

# %%
df_sorted=df.sort_values(by="price",ascending=True)
print("sorted by price:\n",df_sorted,"\n")
# Out:
# sorted by price:
#              date       price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 4567  2014-07-02         0.0       4.0       2.50         4080     18362
# 4405  2014-05-20         0.0       4.0       3.75         3300      4545
# 4408  2014-05-21         0.0       5.0       2.25         2880     11965
# 4411  2014-05-22         0.0       5.0       2.25         2000      7900
# 4499  2014-06-17         0.0       5.0       3.75         3870      8225
# ...          ...         ...       ...        ...          ...       ...
# 2761  2014-06-18   4489000.0       4.0       3.00         6430     27517
# 2654  2014-06-17   4668000.0       5.0       6.75         9640     13068
# 2286  2014-06-11   7062500.0       5.0       4.50        10040     37325
# 4346  2014-06-23  12899000.0       3.0       2.50         2190     11394
# 4350  2014-07-03  26590000.0       3.0       2.00         1180      7793
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            4600 non-null   object
#  1   price           4600 non-null   float64
#  2   bedrooms        4600 non-null   float64
#  3   bathrooms       4600 non-null   float64
#  4   sqft_living     4600 non-null   int64
#  5   sqft_lot        4600 non-null   int64
#  6   floors          4600 non-null   float64
#  7   waterfront      4600 non-null   int64
#  8   view            4600 non-null   int64
#  9   condition       4600 non-null   int64
#  10  sqft_above      4600 non-null   int64
#  11  sqft_basement   4600 non-null   int64
#  12  yr_built        4600 non-null   int64
#  13  yr_renovated    4600 non-null   int64
#  14  street          4600 non-null   object
#  15  city            4600 non-null   object
#  16  statezip        4600 non-null   object
# ...

# %%
print(df.groupby("floors")["sqft_above"].mean())
# Out:
# floors
# 1.0    1336.515639
# 1.5    1658.677928
# 2.0    2440.383766
# 2.5    2813.902439
# 3.0    1750.109375
# 3.5    2232.000000
# Name: sqft_above, dtype: float64

# %%
most_valued=df.loc[df["price"].idxmax()]
print(most_valued)
# Out:
# date                     2014-07-03
# price                    26590000.0
# bedrooms                        3.0
# bathrooms                       2.0
# sqft_living                    1180
# sqft_lot                       7793
# floors                          1.0
# waterfront                        0
# view                              0
# condition                         4
# sqft_above                     1180
# sqft_basement                     0
# yr_built                       1992
# yr_renovated                      0
# street            12005 SE 219th Ct
# city                           Kent
# statezip                   WA 98031
# price_per_sqft              22533.9
# Name: 4350, dtype: object

# %%
df1=df.dropna()
df1

df2=df.dropna(axis=1)
print(df2)
 
df3=df.fillna(0)
print(df3)
 
df3=df.bfill()
df3
 
df3=df.ffill()
df3
# Out:
#             date       price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-05-02   313000.00       3.0       1.50         1340      7912
# 1     2014-05-02  2384000.00       5.0       2.50         3650      9050
# 2     2014-05-02   342000.00       3.0       2.00         1930     11947
# 3     2014-05-02   420000.00       3.0       2.25         2000      8030
# 4     2014-05-02   550000.00       4.0       2.50         1940     10500
# ...          ...         ...       ...        ...          ...       ...
# 4595  2014-07-09   308166.67       3.0       1.75         1510      6360
# 4596  2014-07-09   534333.33       3.0       2.50         1460      7573
# 4597  2014-07-09   416904.17       3.0       2.50         3010      7014
# 4598  2014-07-10   203400.00       4.0       2.00         2090      6630
# 4599  2014-07-10   220600.00       3.0       2.50         1490      8102
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
print(df["price"].dtype)
# Out:
# float64

# %%
result = df[df["city"].str.startswith("Auburn")]
print(result)
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 17    2014-05-02  367500.00       4.0       3.00         3110      7231
# 34    2014-05-02  400000.00       4.0       2.50         3630     42884
# 56    2014-05-02  491500.00       4.0       1.75         2190    125452
# 70    2014-05-04  331950.00       4.0       2.50         2530      9933
# 103   2014-05-05  328000.00       4.0       2.50         2370      6500
# ...          ...        ...       ...        ...          ...       ...
# 4425  2014-05-28   87500.00       2.0       1.00          780      6685
# 4463  2014-06-05  237227.86       4.0       2.50         2068      7242
# 4518  2014-06-20  248400.00       3.0       1.75         1880     11249
# 4520  2014-06-20       0.00       4.0       2.50         1960     11600
# 4593  2014-07-08  289373.31       3.0       2.50         2538      4600
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
result = df["city"].str.replace(r'[^a-zA-Z0-9]','',regex=True)
print(result)
# Out:
# 0       Shoreline
# 1         Seattle
# 2            Kent
# 3        Bellevue
# 4         Redmond
#           ...
# 4595      Seattle
# 4596     Bellevue
# 4597       Renton
# 4598      Seattle
# 4599    Covington
# Name: city, Length: 4600, dtype: object

# %%
result = df[df["waterfront"] == 1]
print(result)
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 381   2014-05-08   988500.0       3.0       2.75         2015     16807
# 404   2014-05-09  2400000.0       3.0       2.25         3000     11665
# 478   2014-05-12  1200000.0       3.0       1.75         1560      8078
# 518   2014-05-12   947500.0       3.0       2.75         2980     27144
# 535   2014-05-12   615000.0       2.0       1.75         2040     28593
# 581   2014-05-13  2555000.0       4.0       2.50         5300     26211
# 1163  2014-05-22   503000.0       2.0       1.75         2860     59612
# 1301  2014-05-24  2000000.0       5.0       4.00         4580      4443
# 1464  2014-05-28  1175000.0       3.0       2.50         1970     23180
# 1639  2014-05-30   800000.0       2.0       2.25         1730     31491
# 2031  2014-06-06  1150000.0       3.0       1.50         2170     16600
# 2083  2014-06-08  2700000.0       4.0       3.25         4420      7850
# ...

# %%
df["Years_Difference"] = df["yr_renovated"] - df["yr_built"]
2
print(df[["yr_built", "yr_renovated", "Years_Difference"]])
# Out:
#       yr_built  yr_renovated  Years_Difference
# 0         1955          2005                50
# 1         1921             0             -1921
# 2         1966             0             -1966
# 3         1963             0             -1963
# 4         1976          1992                16
# ...        ...           ...               ...
# 4595      1954          1979                25
# 4596      1983          2009                26
# 4597      2009             0             -2009
# 4598      1974             0             -1974
# 4599      1990             0             -1990
#
# [4600 rows x 3 columns]
